# %% [markdown]
# # **Regression Models with Keras**

# %% [markdown]
# # Download and Clean Dataset

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented.
# If you run this notebook on a different environment, e.g. your desktop, you may need to uncomment and install certain libraries.

#!pip install numpy==1.21.4
#!pip install pandas==1.3.4
#!pip install keras==2.1.6

# %%
import pandas as pd
import numpy as np

import warnings
warnings.simplefilter('ignore', FutureWarning)

# %% [markdown]
# The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:
#
# 1. Cement
#
# 2. Blast Furnace Slag
#
# 3. Fly Ash
#
# 4. Water
#
# 5. Superplasticizer
#
# 6. Coarse Aggregate
#
# 7. Fine Aggregate

# %%
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# So the first concrete sample has 540 cubic meter of cement, 0 cubic meter of blast furnace slag, 0 cubic meter of fly ash, 162 cubic meter of water, 2.5 cubic meter of superplaticizer, 1040 cubic meter of coarse aggregate, 676 cubic meter of fine aggregate. Such a concrete mix which is 28 days old, has a compressive strength of 79.99 MPa.

# %% [markdown]
# **Let's check how many data points we have.**

# %%
  concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# So, there are approximately 1000 samples to train our model on. Because of the few samples, we have to be careful not to overfit the training data.
#
#
# ---
#
#
#
#
#
#
#
#
# **Let's check the dataset for any missing values.**

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks very clean and is ready to be used to build our model.

# %% [markdown]
# **Split data into predictors and target**
#
# ---
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# Let's do a quick sanity check of the predictors and the target dataframes.

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Finally, the last step is to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Let's save the number of predictors to n_cols since we will need this number when building our network.

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# # Import Keras

# %%
import keras

# %% [markdown]
# * As you can see, the TensorFlow backend was used to install the Keras library.
#
#
#
#
#
#
#
# * Let's import the rest of the packages from the Keras library that we will need to build our regressoin model.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# **Build a Neural Network**

# %% [markdown]
# Let's define a function that defines our regression model for us so that we can conveniently call it to create our model.

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(50, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))

    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# The above function create a model that has two hidden layers, each of 50 hidden units.

# %% [markdown]
# # Train and Test the Network

# %% [markdown]
# Let's call the function now to create our model.

# %%
# build the model
model = regression_model()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Next, we will train and test the model at the same time using the fit method. We will leave out 30% of the data for validation and we will train the model for 100 epochs.

# %%
# fit the model
model.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 1s - 59ms/step - loss: 1618.0607 - val_loss: 1092.3862
# Epoch 2/100
# 23/23 - 0s - 4ms/step - loss: 1462.5686 - val_loss: 928.3585
# Epoch 3/100
# 23/23 - 0s - 6ms/step - loss: 1219.1744 - val_loss: 694.8487
# Epoch 4/100
# 23/23 - 0s - 6ms/step - loss: 877.2056 - val_loss: 434.2626
# Epoch 5/100
# 23/23 - 0s - 3ms/step - loss: 526.1001 - val_loss: 236.9077
# Epoch 6/100
# 23/23 - 0s - 3ms/step - loss: 297.9514 - val_loss: 161.6020
# Epoch 7/100
# 23/23 - 0s - 6ms/step - loss: 220.7882 - val_loss: 157.3500
# Epoch 8/100
# 23/23 - 0s - 6ms/step - loss: 205.3564 - val_loss: 160.8950
# Epoch 9/100
# 23/23 - 0s - 7ms/step - loss: 195.6083 - val_loss: 162.1705
# Epoch 10/100
# 23/23 - 0s - 6ms/step - loss: 188.6416 - val_loss: 160.9818
# Epoch 11/100
# 23/23 - 0s - 4ms/step - loss: 182.5012 - val_loss: 159.7085
# Epoch 12/100
# 23/23 - 0s - 4ms/step - loss: 177.4136 - val_loss: 156.4744
# Epoch 13/100
# 23/23 - 0s - 3ms/step - loss: 173.0175 - val_loss: 154.3329
# Epoch 14/100
# 23/23 - 0s - 7ms/step - loss: 168.6700 - val_loss: 153.6311
# Epoch 15/100
# 23/23 - 0s - 4ms/step - loss: 165.2516 - val_loss: 153.1032
# Epoch 16/100
# 23/23 - 0s - 4ms/step - loss: 161.7982 - val_loss: 151.7582
# Epoch 17/100
# 23/23 - 0s - 6ms/step - loss: 159.0853 - val_loss: 150.4998
# Epoch 18/100
# 23/23 - 0s - 6ms/step - loss: 156.5368 - val_loss: 151.0173
# Epoch 19/100
# 23/23 - 0s - 4ms/step - loss: 153.8624 - val_loss: 147.8012
# Epoch 20/100
# 23/23 - 0s - 6ms/step - loss: 151.8624 - val_loss: 148.1180
# Epoch 21/100
# 23/23 - 0s - 3ms/step - loss: 149.7693 - val_loss: 147.4864
# Epoch 22/100
# 23/23 - 0s - 7ms/step - loss: 148.1111 - val_loss: 146.7309
# Epoch 23/100
# 23/23 - 0s - 6ms/step - loss: 146.5612 - val_loss: 146.3531
# Epoch 24/100
# 23/23 - 0s - 6ms/step - loss: 144.0859 - val_loss: 145.3407
# Epoch 25/100
# 23/23 - 0s - 7ms/step - loss: 142.5967 - val_loss: 144.2820
# Epoch 26/100
# 23/23 - 0s - 6ms/step - loss: 140.1660 - val_loss: 146.8443
# Epoch 27/100
# 23/23 - 0s - 4ms/step - loss: 139.1263 - val_loss: 143.1617
# Epoch 28/100
# 23/23 - 0s - 7ms/step - loss: 137.3725 - val_loss: 143.0653
# Epoch 29/100
# 23/23 - 0s - 5ms/step - loss: 135.6492 - val_loss: 140.7675
# Epoch 30/100
# 23/23 - 0s - 6ms/step - loss: 134.2500 - val_loss: 139.6236
# Epoch 31/100
# 23/23 - 0s - 6ms/step - loss: 132.5340 - val_loss: 139.2021
# Epoch 32/100
# 23/23 - 0s - 4ms/step - loss: 130.7484 - val_loss: 140.4749
# Epoch 33/100
# 23/23 - 0s - 7ms/step - loss: 129.3515 - val_loss: 138.7290
# Epoch 34/100
# 23/23 - 0s - 6ms/step - loss: 127.7173 - val_loss: 139.7836
# Epoch 35/100
# 23/23 - 0s - 6ms/step - loss: 126.2281 - val_loss: 138.2433
# Epoch 36/100
# 23/23 - 0s - 5ms/step - loss: 124.7045 - val_loss: 138.1230
# Epoch 37/100
# 23/23 - 0s - 6ms/step - loss: 123.4958 - val_loss: 134.2742
# Epoch 38/100
# 23/23 - 0s - 14ms/step - loss: 121.6428 - val_loss: 137.5412
# Epoch 39/100
# 23/23 - 0s - 5ms/step - loss: 120.4139 - val_loss: 134.3682
# Epoch 40/100
# 23/23 - 0s - 6ms/step - loss: 118.0380 - val_loss: 135.2120
# Epoch 41/100
# 23/23 - 0s - 6ms/step - loss: 116.1696 - val_loss: 133.6445
# Epoch 42/100
# 23/23 - 0s - 15ms/step - loss: 114.8506 - val_loss: 133.6679
# Epoch 43/100
# 23/23 - 0s - 18ms/step - loss: 112.5603 - val_loss: 132.0685
# Epoch 44/100
# 23/23 - 0s - 8ms/step - loss: 110.8876 - val_loss: 131.8969
# Epoch 45/100
# 23/23 - 0s - 11ms/step - loss: 108.8002 - val_loss: 132.3571
# Epoch 46/100
# 23/23 - 0s - 6ms/step - loss: 106.7880 - val_loss: 130.8322
# Epoch 47/100
# 23/23 - 0s - 5ms/step - loss: 103.8599 - val_loss: 131.6089
# Epoch 48/100
# 23/23 - 0s - 6ms/step - loss: 100.7542 - val_loss: 128.9095
# Epoch 49/100
# 23/23 - 0s - 7ms/step - loss: 97.4625 - val_loss: 128.5600
# Epoch 50/100
# 23/23 - 0s - 6ms/step - loss: 94.4700 - val_loss: 126.4882
# Epoch 51/100
# 23/23 - 0s - 6ms/step - loss: 91.5181 - val_loss: 126.6070
# Epoch 52/100
# 23/23 - 0s - 7ms/step - loss: 87.6580 - val_loss: 126.9855
# Epoch 53/100
# 23/23 - 0s - 6ms/step - loss: 85.2135 - val_loss: 122.9493
# Epoch 54/100
# 23/23 - 0s - 6ms/step - loss: 81.9360 - val_loss: 125.1313
# Epoch 55/100
# 23/23 - 0s - 6ms/step - loss: 79.1514 - val_loss: 122.9128
# Epoch 56/100
# 23/23 - 0s - 7ms/step - loss: 76.2859 - val_loss: 121.8797
# Epoch 57/100
# 23/23 - 0s - 5ms/step - loss: 73.7716 - val_loss: 121.4538
# Epoch 58/100
# 23/23 - 0s - 4ms/step - loss: 71.9211 - val_loss: 121.7249
# Epoch 59/100
# 23/23 - 0s - 6ms/step - loss: 69.1725 - val_loss: 120.6641
# Epoch 60/100
# 23/23 - 0s - 7ms/step - loss: 67.3493 - val_loss: 125.3821
# Epoch 61/100
# 23/23 - 0s - 5ms/step - loss: 65.3581 - val_loss: 119.7846
# Epoch 62/100
# 23/23 - 0s - 6ms/step - loss: 62.8385 - val_loss: 121.5906
# Epoch 63/100
# 23/23 - 0s - 6ms/step - loss: 61.5170 - val_loss: 119.6497
# Epoch 64/100
# 23/23 - 0s - 3ms/step - loss: 60.6521 - val_loss: 119.0775
# Epoch 65/100
# 23/23 - 0s - 7ms/step - loss: 59.0625 - val_loss: 118.9790
# Epoch 66/100
# 23/23 - 0s - 5ms/step - loss: 57.5485 - val_loss: 119.9047
# Epoch 67/100
# 23/23 - 0s - 3ms/step - loss: 56.5016 - val_loss: 121.8513
# Epoch 68/100
# 23/23 - 0s - 4ms/step - loss: 54.9012 - val_loss: 116.6128
# Epoch 69/100
# 23/23 - 0s - 6ms/step - loss: 53.5598 - val_loss: 119.6398
# Epoch 70/100
# 23/23 - 0s - 3ms/step - loss: 52.6389 - val_loss: 118.7154
# Epoch 71/100
# 23/23 - 0s - 6ms/step - loss: 52.3263 - val_loss: 114.3701
# Epoch 72/100
# 23/23 - 0s - 7ms/step - loss: 50.0962 - val_loss: 121.5343
# Epoch 73/100
# 23/23 - 0s - 6ms/step - loss: 49.7620 - val_loss: 117.2215
# Epoch 74/100
# 23/23 - 0s - 4ms/step - loss: 47.6467 - val_loss: 115.0846
# Epoch 75/100
# 23/23 - 0s - 5ms/step - loss: 46.7850 - val_loss: 117.3877
# Epoch 76/100
# 23/23 - 0s - 6ms/step - loss: 46.3278 - val_loss: 114.0064
# Epoch 77/100
# 23/23 - 0s - 4ms/step - loss: 45.6315 - val_loss: 120.2105
# Epoch 78/100
# 23/23 - 0s - 6ms/step - loss: 45.0084 - val_loss: 118.3028
# Epoch 79/100
# 23/23 - 0s - 6ms/step - loss: 43.2273 - val_loss: 116.7454
# Epoch 80/100
# 23/23 - 0s - 6ms/step - loss: 41.9942 - val_loss: 114.4422
# Epoch 81/100
# 23/23 - 0s - 7ms/step - loss: 41.9996 - val_loss: 118.2340
# Epoch 82/100
# 23/23 - 0s - 3ms/step - loss: 41.4431 - val_loss: 116.4949
# Epoch 83/100
# 23/23 - 0s - 3ms/step - loss: 40.0255 - val_loss: 119.1712
# Epoch 84/100
# 23/23 - 0s - 7ms/step - loss: 39.2054 - val_loss: 119.2801
# Epoch 85/100
# 23/23 - 0s - 5ms/step - loss: 38.8826 - val_loss: 115.5127
# Epoch 86/100
# 23/23 - 0s - 7ms/step - loss: 38.3163 - val_loss: 117.6862
# Epoch 87/100
# 23/23 - 0s - 6ms/step - loss: 37.9024 - val_loss: 114.7041
# Epoch 88/100
# 23/23 - 0s - 6ms/step - loss: 37.4199 - val_loss: 109.2383
# Epoch 89/100
# 23/23 - 0s - 3ms/step - loss: 36.6829 - val_loss: 117.4062
# Epoch 90/100
# 23/23 - 0s - 4ms/step - loss: 35.8503 - val_loss: 112.0549
# Epoch 91/100
# 23/23 - 0s - 3ms/step - loss: 35.3548 - val_loss: 113.5838
# Epoch 92/100
# 23/23 - 0s - 6ms/step - loss: 34.5988 - val_loss: 117.3553
# Epoch 93/100
# 23/23 - 0s - 4ms/step - loss: 34.7469 - val_loss: 109.8236
# Epoch 94/100
# 23/23 - 0s - 6ms/step - loss: 34.0957 - val_loss: 111.3553
# Epoch 95/100
# 23/23 - 0s - 3ms/step - loss: 33.4933 - val_loss: 114.5484
# Epoch 96/100
# 23/23 - 0s - 4ms/step - loss: 33.1384 - val_loss: 125.5426
# Epoch 97/100
# 23/23 - 0s - 6ms/step - loss: 32.8591 - val_loss: 111.2654
# Epoch 98/100
# 23/23 - 0s - 6ms/step - loss: 31.9717 - val_loss: 122.8767
# Epoch 99/100
# 23/23 - 0s - 4ms/step - loss: 32.1451 - val_loss: 114.1532
# Epoch 100/100
# 23/23 - 0s - 6ms/step - loss: 31.3634 - val_loss: 116.0057

# %% [markdown]
# You can refer to this link to learn about other functions that you can use for prediction or evaluation.
#
# * Feel free to vary the following and note what impact each change has on the model's performance:
#
# 1. Increase or decreate number of neurons in hidden layers
# 2. Add more hidden layers
# 3. Increase number of epochs

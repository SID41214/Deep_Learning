# %% [markdown]
# <h1>Objective</h1><ul><li> How to create a dataset object.</li></ul>

# %% [markdown]
# <h1>Data Preparation with PyTorch</h1>

# %% [markdown]
# <p>Crack detection has vital importance for structural health monitoring and inspection. We would like to train a network to detect Cracks, we will denote the images that contain cracks as positive and images with no cracks as negative.  In this lab you are going to have to build a dataset object. There are five questions in this lab, Including some questions that are intermediate steps to help you build the dataset object. You are going to have to remember the output for some  of the questions. </p>

# %% [markdown]
# <h2>Table of Contents</h2>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
#
# <ul>
#     <li><a href="#auxiliary"> Imports and Auxiliary Functions </a></li>
#     <li><a href="#download_data"> Download data</a></li>
#     <li><a href="#examine_files">Examine Files</a></li>
#     <li><a href="#Question_1"><b>Question 1:find number of files</b> </a></li>
#     <li><a href="#assign_labels">Assign Labels to Images  </a></li>
#     <li><a href="#Question_2"><b>Question 2 : Assign labels to image </b> </a></li>
#     <li><a href="#split">Training  and Validation  Split </a></li>
#     <li><a href="#Question_3"><b>Question 3: Training  and Validation  Split</b> </a></li>
# <li><a href="#data_class">Create a Dataset Class </a></li>
#     <li><a href="#Question_4"><b>Question 4:Display  training dataset object</b> </a></li>
#     <li><a href="#Question_5"><b>Question 5:Display  validation dataset  object</b> </a></li>
#
# </ul>
# <p>Estimated Time Needed: <strong>25 min</strong></p>
#  </div>
# <hr>

# %% [markdown]
# <h2 id="auxiliary">Imports and Auxiliary Functions</h2>

# %% [markdown]
# The following are the libraries we are going to use for this lab:

# %%
# !pip install skillsnetwork
# Out:
# Collecting skillsnetwork
#   Obtaining dependency information for skillsnetwork from https://files.pythonhosted.org/packages/2e/90/3f5a71435ddf90467a9c33669602c97c20acbe784822676db87c6aff0827/skillsnetwork-0.21.10-py3-none-any.whl.metadata
#   Downloading skillsnetwork-0.21.10-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: ipython in c:\users\sid41\anaconda3\lib\site-packages (from skillsnetwork) (8.15.0)
# Requirement already satisfied: ipywidgets<=8.1.3 in c:\users\sid41\anaconda3\lib\site-packages (from skillsnetwork) (8.0.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\sid41\anaconda3\lib\site-packages (from skillsnetwork) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4 in c:\users\sid41\anaconda3\lib\site-packages (from skillsnetwork) (4.65.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\sid41\anaconda3\lib\site-packages (from ipywidgets<=8.1.3->skillsnetwork) (6.25.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\sid41\anaconda3\lib\site-packages (from ipywidgets<=8.1.3->skillsnetwork) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\sid41\anaconda3\lib\site-packages (from ipywidgets<=8.1.3->skillsnetwork) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\sid41\anaconda3\lib\site-packages (from ipywidgets<=8.1.3->skillsnetwork) (3.0.5)
# Requirement already satisfied: backcall in c:\users\sid41\anaconda3\lib\site-packages (from ipython->skillsnetwork) (0.2.0)
# Requirement already satisfied: decorator in c:\users\sid41\anaconda3\lib\site-packages (from ipython->skillsnetwork) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\sid41\anaconda3\lib\site-packages (from ipython->skillsnetwork) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\sid41\anaconda3\lib\site-packages (from ipython->skillsnetwork) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\sid41\anaconda3\lib\site-packages (from ipython->skillsnetwork) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\sid41\anaconda3\lib\site-packages (from ipython->skillsnetwork) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\sid41\anaconda3\lib\site-packages (from ipython->skillsnetwork) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\sid41\anaconda3\lib\site-packages (from ipython->skillsnetwork) (0.2.0)
# Requirement already satisfied: colorama in c:\users\sid41\anaconda3\lib\site-packages (from ipython->skillsnetwork) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sid41\anaconda3\lib\site-packages (from requests<3,>=2->skillsnetwork) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sid41\anaconda3\lib\site-packages (from requests<3,>=2->skillsnetwork) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sid41\anaconda3\lib\site-packages (from requests<3,>=2->skillsnetwork) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sid41\anaconda3\lib\site-packages (from requests<3,>=2->skillsnetwork) (2023.7.22)
# Requirement already satisfied: comm>=0.1.1 in c:\users\sid41\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\sid41\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\sid41\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\sid41\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (5.3.0)
# Requirement already satisfied: nest-asyncio in c:\users\sid41\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (1.5.6)
# Requirement already satisfied: packaging in c:\users\sid41\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (23.1)
# Requirement already satisfied: psutil in c:\users\sid41\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in c:\users\sid41\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\sid41\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (6.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\sid41\anaconda3\lib\site-packages (from jedi>=0.16->ipython->skillsnetwork) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\sid41\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->skillsnetwork) (0.2.5)
# Requirement already satisfied: executing in c:\users\sid41\anaconda3\lib\site-packages (from stack-data->ipython->skillsnetwork) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\sid41\anaconda3\lib\site-packages (from stack-data->ipython->skillsnetwork) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\sid41\anaconda3\lib\site-packages (from stack-data->ipython->skillsnetwork) (0.2.2)
# Requirement already satisfied: entrypoints in c:\users\sid41\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sid41\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\sid41\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\sid41\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (305.1)
# Requirement already satisfied: six in c:\users\sid41\anaconda3\lib\site-packages (from asttokens->stack-data->ipython->skillsnetwork) (1.16.0)
# Downloading skillsnetwork-0.21.10-py3-none-any.whl (26 kB)
# Installing collected packages: skillsnetwork
# Successfully installed skillsnetwork-0.21.10

# %%
# !pip install torch

# %%
from PIL import Image
import matplotlib.pyplot as plt
import os
import glob
import torch
from torch.utils.data import Dataset
import skillsnetwork
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       3 import os
#       4 import glob
# ----> 5 import torch
#       6 from torch.utils.data import Dataset
#       7 import skillsnetwork
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# We will use this function in the lab to plot:

# %%
def show_data(data_sample, shape = (28, 28)):
    plt.imshow(data_sample[0].numpy().reshape(shape), cmap='gray')
    plt.title('y = ' + data_sample[1])

# %% [markdown]
# <h2 id="download_data">Download Data</h2>

# %% [markdown]
# In this section, you are going to download the data from IBM object storage using **skillsnetwork.prepare** command. <b>skillsnetwork.prepare</b> is a command that's used to download a zip file, unzip it and store it in a specified directory. Locally we store the data in the directory  **/resources/data**.

# %%
import os
if not os.path.exists('/resources/data'):
    os.makedirs('/resources/data')
await skillsnetwork.prepare("https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/concrete_crack_images_for_classification.zip", path = "/resources/data", overwrite=True)
# Out:
# Downloading concrete_crack_images_for_classification.zip:   0%|          | 0/245259777 [00:00<?, ?it/s]
#   0%|          | 0/40000 [00:00<?, ?it/s]
# Saved to '../resources/data'

# %% [markdown]
# We then download the files that contain the negative images:

# %% [markdown]
# <h2 id="examine_files">Examine Files </h2>

# %% [markdown]
# In the previous lab, we create two lists; one to hold the path to the Negative files and one to hold the path to the Positive files. This process is shown in the following few lines of code.

# %% [markdown]
# We can obtain the list that contains the path to the <b>negative files</b> as follows:

# %%
directory="/resources/data"
negative='Negative'
negative_file_path=os.path.join(directory,negative)
negative_files=[os.path.join(negative_file_path,file) for file in  os.listdir(negative_file_path) if file.endswith(".jpg")]
negative_files.sort()
negative_files[0:3]
# Out:
# ['/resources/data/Negative/00001.jpg',
#  '/resources/data/Negative/00002.jpg',
#  '/resources/data/Negative/00003.jpg']

# %% [markdown]
# We can obtain the list that contains the path to the <b>positive files</b> files as follows:

# %%
positive="Positive"
positive_file_path=os.path.join(directory,positive)
positive_files=[os.path.join(positive_file_path,file) for file in  os.listdir(positive_file_path) if file.endswith(".jpg")]
positive_files.sort()
positive_files[0:3]
# Out:
# ['/resources/data/Positive/00001.jpg',
#  '/resources/data/Positive/00002.jpg',
#  '/resources/data/Positive/00003.jpg']

# %% [markdown]
# <h2 id="Question_1">Question 1</h2>
# <b>Find the <b>combined</b> length of the list <code>positive_files</code> and <code>negative_files</code> using the function <code>len</code> . Then assign  it to the variable <code>number_of_samples</code></b>

# %%
number_of_samples = len(positive_files) + len(negative_files)
print("Total number of samples:", number_of_samples)
# Out:
# Total number of samples: 40000

# %% [markdown]
# <h2 id="assign_labels">Assign Labels to Images </h2>

# %% [markdown]
# In this section we will assign a label to each image in this case we  can assign the positive images, i.e images with a crack to a value one  and the negative images i.e images with out a crack to a value of zero <b>Y</b>. First we create a tensor or vector of zeros, each element corresponds to a new sample. The length of the tensor is equal to the number of samples.

# %%
Y=torch.zeros([number_of_samples])

# %% [markdown]
# As we are using the tensor <b>Y</b> for classification we cast it to a <code>LongTensor</code>.

# %%
Y=Y.type(torch.LongTensor)
Y.type()
# Out:
# 'torch.LongTensor'

# %% [markdown]
# With respect to each element we will set the even elements to class one and the odd elements to class zero.

# %%
Y[::2]=1
Y[1::2]=0

# %% [markdown]
# <h2 id="Question_2">Question 2</h2>
# <b>Create a list all_files such that the even indexes contain the path to images with positive or cracked samples and the odd element contain the negative images or images with out cracks. Then use the following code to print out the first four samples.</b>

# %%
# Make sure both lists are sorted and have equal length
all_files = [val for pair in zip(positive_files, negative_files) for val in pair]

# Print first four samples
print(all_files[:4])
# Out:
# ['/resources/data/Positive/00001.jpg', '/resources/data/Negative/00001.jpg', '/resources/data/Positive/00002.jpg', '/resources/data/Negative/00002.jpg']

# %% [markdown]
# code used to print samples:

# %%
for y,file in zip(Y, all_files[0:4]):
    plt.imshow(Image.open(file))
    plt.title("y="+str(y.item()))
    plt.show()

# %% [markdown]
# <h2 id="split">Training  and Validation  Split  </h2>
# When training the model we  split up our data into training and validation data. It If the variable train is set to <code>True</code>  the following lines of code will segment the  tensor <b>Y</b> such at  the first 30000 samples are used for training. If the variable train is set to <code>False</code> the remainder of the samples will be used for validation data.

# %%
train=False

if train:
    all_files=all_files[0:30000]
    Y=Y[0:30000]

else:
    all_files=all_files[30000:]
    Y=Y[30000:]

# %% [markdown]
# <h2 id="Question_3">Question 3</h2>
# Modify the above lines of code such that if the variable <code>train</code> is set to <c>True</c> the first 30000 samples of all_files are use in training. If <code>train</code> is set to <code>False</code> the remaining  samples are used for validation. In both cases reassign  the values to the variable all_files, then use the following lines of code to print out the first four validation sample images.

# %%
# Define how many samples to use for training
train_samples = 30000

# Split all_files and Y based on train flag
if train:
    all_files = all_files[:train_samples]
    Y = Y[:train_samples]
else:
    all_files = all_files[train_samples:]
    Y = Y[train_samples:]

# Display the first four validation images (this will work correctly whether train=True or False)
for y, file in zip(Y[:4], all_files[:4]):
    plt.imshow(Image.open(file))
    plt.title("y = " + str(y.item()))
    plt.axis('off')  # Optional: hides the axis
    plt.show()

# %% [markdown]
# Just a note the images printed out in question two are the first four training samples.

# %% [markdown]
# <h2 id="data_class">Create a Dataset Class</h2>

# %% [markdown]
# In this section, we will use the previous code to build a dataset class.

# %% [markdown]
# Complete the code to build a Dataset class <code>dataset</code>. As before, make sure the even samples are positive, and the odd samples are negative.  If the parameter <code>train</code> is set to <code>True</code>, use the first 30 000  samples as training data; otherwise, the remaining samples will be used as validation data.

# %%
class Dataset(Dataset):

    # Constructor
    def __init__(self,transform=None,train=True):
        directory="/resources/data"
        positive="Positive"
        negative="Negative"

        positive_file_path=os.path.join(directory,positive)
        negative_file_path=os.path.join(directory,negative)
        positive_files=[os.path.join(positive_file_path,file) for file in  os.listdir(positive_file_path) if file.endswith(".jpg")]
        positive_files.sort()
        negative_files=[os.path.join(negative_file_path,file) for file in  os.listdir(negative_file_path) if file.endswith(".jpg")]
        negative_files.sort()

        self.all_files=[None]*number_of_samples
        self.all_files[::2]=positive_files
        self.all_files[1::2]=negative_files
        # The transform is goint to be used on image
        self.transform = transform
        #torch.LongTensor
        self.Y=torch.zeros([number_of_samples]).type(torch.LongTensor)
        self.Y[::2]=1
        self.Y[1::2]=0

        if train:

            self.Y=self.Y[0:30000]
            self.len=len(self.all_files)
        else:

            self.Y=self.Y[30000:]
            self.len=len(self.all_files)





    # Get the length
    def __len__(self):
        return self.len

    # Getter
    def __getitem__(self, idx):


        image=Image.open(self.all_files[idx])
        y=self.Y[idx]


        # If there is any transform method, apply it onto the image
        if self.transform:
            image = self.transform(image)

        return image, y

# %% [markdown]
# <h2 id="Question_4">Question 4</h2>
# <b>Create a Dataset object <code>dataset</code> for the training data, use the following lines of code to print out sample the 10th and  sample 100 (remember zero indexing)  </b>

# %%
from torchvision import transforms
import matplotlib.pyplot as plt

# Define the transform for preprocessing (resizing + tensor conversion)
transform = transforms.Compose([
    transforms.Resize((100, 100)),
    transforms.ToTensor()
])
# Set train = True to load training samples
dataset = Dataset(transform=transform, train=True)
# Define the sample indices
samples = [10, 100]

# Plot the selected samples
for sample in samples:
    plt.imshow(dataset[sample][0].permute(1, 2, 0))  # Convert tensor from CHW to HWC
    plt.xlabel("y = " + str(dataset[sample][1].item()))
    plt.title("Training data, sample {}".format(sample))
    plt.axis('off')
    plt.show()


# for sample  in samples:
#     plt.imshow(dataset[sample][0])
#     plt.xlabel("y="+str(dataset[sample][1].item()))
#     plt.title("training data, sample {}".format(int(sample)))
#     plt.show()

# %% [markdown]
# We now have all the tools to create a list with the path to each image file.  We use a List Comprehensions  to make the code more compact. We assign it to the variable <code>negative_files<code> , sort it in and display the first three elements:

# %% [markdown]
# <h2 id="Question_5">Question 5</h2>
# <b>Create a Dataset object <code>dataset</code> for the validation  data, use the following lines of code to print out the 16 th and  sample 103 (remember zero indexing)   </b>

# %%
from torchvision import transforms
import matplotlib.pyplot as plt

# Define the transform: resize image and convert to tensor
transform = transforms.Compose([
    transforms.Resize((100, 100)),
    transforms.ToTensor()
])
# Set train=False to load validation samples
dataset = Dataset(transform=transform, train=False)
samples = [16, 103]

for sample in samples:
    # Plot the image
    plt.imshow(dataset[sample][0].permute(1, 2, 0))  # Convert CHW to HWC
    plt.xlabel("y=" + str(dataset[sample][1].item()))
    plt.title("Validation data, sample {}".format(int(sample)))
    plt.axis('off')
    plt.show()



# for sample  in samples:
#     plt.imshow(dataset[sample][0])
#     plt.xlabel("y="+str(dataset[sample][1].item()))
#     plt.title("validation data, sample {}".format(int(sample)))
#     plt.show()
